# %%
from bs4 import BeautifulSoup

with open("Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums.html","r") as html_file:
    content = html_file.read()
    
soup = BeautifulSoup(content, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0100)https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/ -->
# <html class="has-js template-thread_view has-no-touchevents has-passiveeventlisteners has-no-hiddenscroll has-pointer-nav" data-app="public" data-container-key="node-465" data-content-key="thread-3689040" data-cookie-prefix="xf_" data-csrf="1647284239,08c3fc9af2c21a950d8541b5d62bffd0" data-logged-in="false" data-template="thread_view" dir="LTR" id="XF" lang="en-US">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/publishertag.prebid.117.js" type="text/javascript">
#   </script>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/localstore.js" type="text/javascript">
#   </script>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/localstore(1).js" type="text/javascript">
#   </script>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
#   <title>
#    Smogon's Official Ladder Tournament VIII - Replay Thread | Smogon Forums
#   </title>
#   <meta content="(art by ium) (thread format stolen from Vileman)
#
# This thread is a collection of the replays in the playoffs stage of Official Ladder Tournament VIII. For..." name="description"/>
#   <meta content="(art by ium) (thread format stolen from Vileman)
#
# This thread is a collection of the replays in the playoffs stage of Official Ladder Tournament VIII. For information on the format of OLT, please read the introductory thread.
#
# :clefable: - Round 1 - :clefable:
# Sagiri vs Ahsan-219 - 1 | 2 | 3..." property="og:description"/>
#   <meta content="(art by ium) (thread format stolen from Vileman)
#
# This thread is a collection of the replays in the playoffs stage of Official Ladder Tournament VIII. For information on the format of OLT, please..." property="twitter:description"/>
#   <meta content="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/" property="og:url"/>
#   <link href="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/" rel="canonical"/>
#   <meta content="Smogon Forums" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Smogon's Official Ladder Tournament VIII - Replay Thread" property="og:title"/>
#   <meta content="Smogon's Official Ladder Tournament VIII - Replay Thread" property="twitter:title"/>
#   <meta content="https://www.smogon.com/forums/media/twitter.png" property="og:image"/>
#   <meta content="https://www.smogon.com/forums/media/twitter.png" property="twitter:image"/>
#   <meta content="summary" property="twitter:card"/>
#   <meta content="#6363b0" name="theme-color"/>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/rules-p-Hwnr8j7tWA3Nu.js">
#   </script>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/quant.js" type="text/javascript">
#   </script>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/cmp2.js" type="text/javascript">
#   </script>
#   <script async="" data-mode="scan" data-site-id="613206cd1f2bbd4053f45a1d" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/ad-manager.min.js" type="text/javascript">
#   </script>
#   <script>
#    window.top.__vm_add = window.top.__vm_add || [];
#     (function (success) {
#         if (window.document.readyState !== "loading") {
#             success();
#         } else {
#             window.document.addEventListener("DOMContentLoaded", function () {
#                 success();
#             });
#         }
#     })(function () {
#         var placement = document.createElement("div");
#         placement.setAttribute("class", "vm-placement");
#         if (window.innerWidth > 1000) {
#             placement.setAttribute("data-id", "61c1e3b9058691726d94baec"); // 728x90 static forum
#         } else {
#             placement.setAttribute("data-id", "61c1e3a90b7b5c349cf3c689"); // 300x50 dynamic mobile forum
#         }
#
#         document.querySelector("#adholder").appendChild(placement);
#         window.top.__vm_add.push(placement);
#
# 		if (true) {
# 			var placement = document.createElement("div");
#             placement.setAttribute("class", "vm-placement");
#             // Rich Media [forum]
#             placement.setAttribute("data-id", "61c19cf10b7b5c349cf3c576");
#             document.querySelector("#adholder").appendChild(placement);
# 			window.top.__vm_add.push(placement);
# 		}
#     });
#   </script>
#   <link as="font" crossorigin="anonymous" href="https://www.smogon.com/forums/styles/fonts/fa/fa-regular-400.woff2?_v=5.12.1" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://www.smogon.com/forums/styles/fonts/fa/fa-solid-900.woff2?_v=5.12.1" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://www.smogon.com/forums/styles/fonts/fa/fa-brands-400.woff2?_v=5.12.1" rel="preload" type="font/woff2"/>
#   <link href="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/css.php" rel="stylesheet"/>
#   <link href="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/smogon.css.m.1647259251" rel="stylesheet"/>
#   <link href="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/css(1).php" rel="stylesheet"/>
#   <script src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/preamble.min.js">
#   </script>
#   <style>
#    .vm-placement {display:flex} .vm-placement iframe {display: block; margin: 0;}
#   </style>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/gpt.js" type="text/javascript">
#   </script>
#   <style>
#    .vm-placement[data-rejected=true]>div[id^=google_ads_iframe] {
#                         display: none;
#                     }
#   </style>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/org" type="text/javascript">
#   </script>
#   <link href="https://www.smogon.com/forums/media/twitter.png" rel="apple-touch-icon"/>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/apstag.js" type="text/javascript">
#   </script>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/static.min.js" type="text/javascript">
#   </script>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/choice.js" type="text/javascript">
#   </script>
#   <script async="" crossorigin="anonymous" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/recovery" type="text/javascript">
#   </script>
#   <meta content="AxujKG9INjsZ8/gUq8+dTruNvk7RjZQ1oFhhgQbcTJKDnZfbzSTE81wvC2Hzaf3TW4avA76LTZEMdiedF1vIbA4AAABueyJvcmlnaW4iOiJodHRwczovL2ltYXNkay5nb29nbGVhcGlzLmNvbTo0NDMiLCJmZWF0dXJlIjoiVHJ1c3RUb2tlbnMiLCJleHBpcnkiOjE2NTI3NzQ0MDAsImlzVGhpcmRQYXJ0eSI6dHJ1ZX0=" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="A88BWHFjcawUfKU3lIejLoryXoyjooBXLgWmGh+hNcqMK44cugvsI5YZbNarYvi3roc1fYbHA1AVbhAtuHZflgEAAAB2eyJvcmlnaW4iOiJodHRwczovL2dvb2dsZS5jb206NDQzIiwiZmVhdHVyZSI6IlRydXN0VG9rZW5zIiwiZXhwaXJ5IjoxNjUyNzc0NDAwLCJpc1N1YmRvbWFpbiI6dHJ1ZSwiaXNUaGlyZFBhcnR5Ijp0cnVlfQ==" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/pubads_impl_2022030901.js">
#   </script>
#   <style type="text/css">
#    .qc-cmp-button {    background-color: #808080 !important;    border-color: #808080 !important;  }  .qc-cmp-button:hover {    border-color: #808080 !important;  }  .qc-cmp-alt-action,  .qc-cmp-link {    color: #808080 !important;  }  .qc-cmp-button.qc-cmp-secondary-button:hover {    background-color: #808080 !important;    border-color: #808080 !important;  }  .qc-cmp-button.qc-cmp-secondary-button:hover {    color: #ffffff !important;  }  .qc-cmp-button.qc-cmp-secondary-button {    color: #808080 !important;  }  .qc-cmp-button.qc-cmp-secondary-button {    background-color: #eee !important;    border-color: transparent !important;  }  .qc-cmp-small-toggle.qc-cmp-toggle-on,  .qc-cmp-toggle.qc-cmp-toggle-on {    background-color: #778890!important;    border-color: #778890!important;  } #qc-cmp2-ui .qc-cmp2-summary-buttons button[mode="primary"] {margin-top: 47px;order:0;}.qc-cmp2-persistent-link { display: none !important;}a.sc-iwsKbI.jiiVkd.qc-cmp2-persistent-link { display: none;}
#   </style>
#   <style>
#    .vm-skin,.vm-skin-left-ads-container,.vm-skin-right-ads-container { overflow: visible !important; } .vm-footer { display: none !important } [vm-ab-detected="true"].up-show { max-width: none !important; display: block !important; } [vm-ab-detected="true"].up-show > div[id^="google_ads_iframe"] { display: block !important; }
#   </style>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/gpt(1).js" type="text/javascript">
#   </script>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/f(1).txt" type="text/javascript">
#   </script>
#   <script async="" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/pubads_impl_2022030901(1).js" type="text/javascript">
#   </script>
#   <link as="script" href="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/f(1).txt" rel="preload"/>
#   <script src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/f(1).txt" type="text/javascript">
#   </script>
#   <style id="bt-render-styles" type="text/css">
#    .up-hide { display: none !important; }.ahover + [id^="google_ads_iframe_"] { width: 1px !important; height:1px !important; display: grid !important; }
#   </style>
#   <style>
#    @charset "UTF-8";
#
# /********* public:member_tooltip.less ********/
# .memberTooltip-header{display:table;table-layout:fixed;width:100%;padding:6px;background:#fefefe;border-bottom:1px solid #dfdfdf;background:linear-gradient(0deg, #ececec, #f9f9f9)}.memberTooltip-avatar{display:table-cell;width:108px;vertical-align:top}.memberTooltip-headerInfo{display:table-cell;vertical-align:top}.memberTooltip-name{margin:0;margin-top:-.15em;padding:0;font-weight:400;line-height:1.12;font-size:24px;color:#444498}.memberTooltip-name a{color:inherit;text-decoration:none}.memberTooltip-name a:hover{text-decoration:underline}.memberTooltip-headerAction{float:right}.memberTooltip-banners,.memberTooltip-blurb{margin-top:.25em}.memberTooltip-blurb{font-size:13px}.memberTooltip-stats{font-size:13px}.memberTooltip-stats dl.pairs.pairs--rows>dt{font-size:12px}.memberTooltip-info,.memberTooltip-actions{padding:6px}.memberTooltip-separator{margin:-1px 6px 0;border:none;border-top:1px solid #dfdfdf}@media (max-width:480px){.memberTooltip-avatar{width:76px}.memberTooltip-avatar .avatar{width:64px;height:64px;font-size:38px}}
#   </style>
#  </head>
#  <body data-gr-ext-installed="" data-new-gr-c-s-check-loaded="14.1043.0" data-template="thread_view">
#   <!-- Google Tag Manager (noscript) -->
#   <!--<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-KT65CM8"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>-->
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="p-pageWrapper" id="top">
#    <header class="p-header" id="header">
#     <div class="p-header-inner">
#      <div class="p-header-content">
#       <div class="p-header-logo p-header-logo--image">
#        <a href="https://www.smogon.com/forums/">
#         <img alt="Smogon Forums" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/zracknel-beta.svg.m.1"/>
#        </a>
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="p-navSticky p-navSticky--primary is-sticky" data-xf-init="sticky-header">
#     <nav class="p-nav">
#      <div class="p-nav-inner">
#       <a class="p-nav-menuTrigger" data-menu=".js-headerOffCanvasMenu" data-xf-click="off-canvas" role="button" tabindex="0">
#        <i aria-hidden="true">
#        </i>
#        <span class="p-nav-menuText">
#         Menu
#        </span>
#       </a>
#       <div class="p-nav-smallLogo">
#        <a href="https://www.smogon.com/forums/">
#         <img alt="Smogon Forums" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/zracknel-beta.svg.m.1"/>
#        </a>
#       </div>
#       <div class="p-nav-scroller hScroller" data-auto-scroll=".p-navEl.is-selected" data-xf-init="h-scroller">
#        <div class="hScroller-scroll is-calculated" style="margin-bottom: -47px;">
#         <ul class="p-nav-list js-offCanvasNavSource">
#          <li>
#           <div class="p-navEl">
#            <a class="p-navEl-link" data-nav-id="home" href="https://www.smogon.com/">
#             Home
#            </a>
#           </div>
#          </li>
#          <li>
#           <div class="p-navEl">
#            <a class="p-navEl-link" data-nav-id="dex" href="https://www.smogon.com/dex/">
#             Dex
#            </a>
#           </div>
#          </li>
#          <li>
#           <div class="p-navEl">
#            <a class="p-navEl-link" data-nav-id="articles" href="https://www.smogon.com/articles/">
#             Articles
#            </a>
#           </div>
#          </li>
#          <li>
#           <div class="p-navEl is-selected" data-has-children="true">
#            <a class="p-navEl-link p-navEl-link--splitMenu" data-nav-id="forums" href="https://www.smogon.com/forums/" rel="noopener">
#             Forums
#            </a>
#            <a aria-expanded="false" aria-haspopup="true" aria-label="Toggle expanded" class="p-navEl-splitTrigger" data-menu-pos-ref="&lt; .p-navEl" data-xf-click="menu" role="button" tabindex="0">
#            </a>
#            <div aria-hidden="true" class="menu menu--structural" data-menu="menu">
#             <div class="menu-content">
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="whatsNew" href="https://www.smogon.com/forums/whats-new/">
#               What's new
#              </a>
#              <a class="menu-linkRow u-indentDepth1 js-offCanvasCopy" data-nav-id="whatsNewPosts" href="https://www.smogon.com/forums/whats-new/posts/" rel="nofollow">
#               New posts
#              </a>
#              <a class="menu-linkRow u-indentDepth1 js-offCanvasCopy" data-nav-id="whatsNewProfilePosts" href="https://www.smogon.com/forums/whats-new/profile-posts/" rel="nofollow">
#               New profile posts
#              </a>
#              <a class="menu-linkRow u-indentDepth1 js-offCanvasCopy" data-nav-id="latestActivity" href="https://www.smogon.com/forums/whats-new/latest-activity" rel="nofollow">
#               Latest activity
#              </a>
#              <hr class="menu-separator"/>
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="searchForums" href="https://www.smogon.com/forums/search/?type=post">
#               Search forums
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <div class="p-navEl" data-has-children="true">
#            <a class="p-navEl-link p-navEl-link--splitMenu" data-nav-id="members" href="https://www.smogon.com/forums/members/">
#             Users
#            </a>
#            <a aria-expanded="false" aria-haspopup="true" aria-label="Toggle expanded" class="p-navEl-splitTrigger" data-menu-pos-ref="&lt; .p-navEl" data-xf-click="menu" role="button" tabindex="0">
#            </a>
#            <div aria-hidden="true" class="menu menu--structural" data-menu="menu">
#             <div class="menu-content">
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="registeredMembers" href="https://www.smogon.com/forums/members/list/">
#               Registered members
#              </a>
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="currentVisitors" href="https://www.smogon.com/forums/online/">
#               Current visitors
#              </a>
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="newProfilePosts" href="https://www.smogon.com/forums/whats-new/profile-posts/" rel="nofollow">
#               New profile posts
#              </a>
#              <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="searchProfilePosts" href="https://www.smogon.com/forums/search/?type=profile_post">
#               Search profile posts
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <div class="p-navEl">
#            <a class="p-navEl-link" data-nav-id="ps" href="http://play.pokemonshowdown.com/?_ga=2.200699758.1722486498.1551900143-447837285.1543556589" style="padding-left: 32px; background: url(https://play.pokemonshowdown.com/favicon-16.png) no-repeat scroll 10px 50%; border-radius: 2px 2px 0 0;">
#             Play online!
#            </a>
#           </div>
#          </li>
#          <li>
#           <div class="p-navEl">
#            <a class="p-navEl-link" data-nav-id="discord" href="https://discord.gg/smogon" style="padding-left: 35px; background-image: url(/media/discord.png.m.1); background-repeat:no-repeat; background-size: 18px 18px; background-position:10px 50%;border-radius: 2px 2px 0 0;">
#             Live chat!
#            </a>
#           </div>
#          </li>
#         </ul>
#        </div>
#        <i aria-hidden="true" class="hScroller-action hScroller-action--end">
#        </i>
#        <i aria-hidden="true" class="hScroller-action hScroller-action--start">
#        </i>
#       </div>
#       <div class="p-nav-opposite">
#        <div class="p-navgroup p-account p-navgroup--guest">
#         <a class="p-navgroup-link p-navgroup-link--textual p-navgroup-link--logIn" data-follow-redirects="on" data-xf-click="overlay" href="https://www.smogon.com/forums/login/">
#          <span class="p-navgroup-linkText">
#           Log in
#          </span>
#         </a>
#         <a class="p-navgroup-link p-navgroup-link--textual p-navgroup-link--register" data-follow-redirects="on" data-xf-click="overlay" href="https://www.smogon.com/forums/register/">
#          <span class="p-navgroup-linkText">
#           Register
#          </span>
#         </a>
#        </div>
#        <div class="p-navgroup p-discovery">
#         <a aria-label="What's new" class="p-navgroup-link p-navgroup-link--iconic p-navgroup-link--whatsnew" href="https://www.smogon.com/forums/whats-new/" title="What's new">
#          <i aria-hidden="true">
#          </i>
#          <span class="p-navgroup-linkText">
#           What's new
#          </span>
#         </a>
#         <a aria-expanded="false" aria-haspopup="true" aria-label="Search" class="p-navgroup-link p-navgroup-link--iconic p-navgroup-link--search" data-xf-click="menu" href="https://www.smogon.com/forums/search/" title="Search">
#          <i aria-hidden="true">
#          </i>
#          <span class="p-navgroup-linkText">
#           Search
#          </span>
#         </a>
#         <div aria-hidden="true" class="menu menu--structural menu--wide" data-menu="menu">
#          <form action="https://www.smogon.com/forums/search/search" class="menu-content" data-xf-init="quick-search" method="post">
#           <h3 class="menu-header">
#            Search
#           </h3>
#           <div class="menu-row">
#            <div class="inputGroup inputGroup--joined">
#             <input aria-label="Search" class="input" data-menu-autofocus="true" name="keywords" placeholder="Search…" type="text"/>
#             <select aria-label="Search within" class="js-quickSearch-constraint input" name="constraints" style="width: 106px; flex-grow: 0; flex-shrink: 0;">
#              <option value="">
#               Everywhere
#              </option>
#              <option value='{"search_type":"post"}'>
#               Threads
#              </option>
#              <option value='{"search_type":"post","c":{"nodes":[465],"child_nodes":1}}'>
#               This forum
#              </option>
#              <option selected="selected" value='{"search_type":"post","c":{"thread":3689040}}'>
#               This thread
#              </option>
#             </select>
#            </div>
#           </div>
#           <div class="menu-row">
#            <label class="iconic">
#             <input name="c[title_only]" type="checkbox" value="1"/>
#             <i aria-hidden="true">
#             </i>
#             <span class="iconic-label">
#              Search titles only
#             </span>
#            </label>
#           </div>
#           <div class="menu-row">
#            <div class="inputGroup">
#             <span class="inputGroup-text" id="ctrl_search_menu_by_member">
#              By:
#             </span>
#             <input aria-labelledby="ctrl_search_menu_by_member" autocomplete="off" class="input" data-xf-init="auto-complete" name="c[users]" placeholder="Member" type="text"/>
#            </div>
#           </div>
#           <div class="menu-footer">
#            <span class="menu-footer-controls">
#             <button class="button--primary button button--icon button--icon--search" type="submit">
#              <span class="button-text">
#               Search
#              </span>
#             </button>
#             <a class="button" href="https://www.smogon.com/forums/search/">
#              <span class="button-text">
#               Advanced search…
#              </span>
#             </a>
#            </span>
#           </div>
#           <input name="_xfToken" type="hidden" value="1647284426,37ed48919abaa376a25e6f520fd98dcf"/>
#          </form>
#         </div>
#        </div>
#       </div>
#      </div>
#     </nav>
#    </div>
#    <div class="p-sectionLinks">
#     <div class="p-sectionLinks-inner hScroller" data-xf-init="h-scroller">
#      <div class="hScroller-scroll is-calculated" style="margin-bottom: -47px;">
#       <ul class="p-sectionLinks-list">
#        <li>
#         <div class="p-navEl" data-has-children="true">
#          <a class="p-navEl-link p-navEl-link--splitMenu" data-nav-id="whatsNew" href="https://www.smogon.com/forums/whats-new/">
#           What's new
#          </a>
#          <a aria-expanded="false" aria-haspopup="true" aria-label="Toggle expanded" class="p-navEl-splitTrigger" data-menu-pos-ref="&lt; .p-navEl" data-xf-click="menu" role="button" tabindex="0">
#          </a>
#          <div aria-hidden="true" class="menu menu--structural" data-menu="menu">
#           <div class="menu-content">
#            <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="whatsNewPosts" href="https://www.smogon.com/forums/whats-new/posts/" rel="nofollow">
#             New posts
#            </a>
#            <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="whatsNewProfilePosts" href="https://www.smogon.com/forums/whats-new/profile-posts/" rel="nofollow">
#             New profile posts
#            </a>
#            <a class="menu-linkRow u-indentDepth0 js-offCanvasCopy" data-nav-id="latestActivity" href="https://www.smogon.com/forums/whats-new/latest-activity" rel="nofollow">
#             Latest activity
#            </a>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li>
#         <div class="p-navEl">
#          <a class="p-navEl-link" data-nav-id="searchForums" href="https://www.smogon.com/forums/search/?type=post">
#           Search forums
#          </a>
#         </div>
#        </li>
#       </ul>
#      </div>
#      <i aria-hidden="true" class="hScroller-action hScroller-action--end">
#      </i>
#      <i aria-hidden="true" class="hScroller-action hScroller-action--start">
#      </i>
#     </div>
#    </div>
#    <div aria-hidden="true" class="offCanvasMenu offCanvasMenu--nav js-headerOffCanvasMenu" data-menu="menu" data-ocm-builder="navigation">
#     <div class="offCanvasMenu-backdrop" data-menu-close="true">
#     </div>
#     <div class="offCanvasMenu-content">
#      <div class="offCanvasMenu-header">
#       Menu
#       <a aria-label="Close" class="offCanvasMenu-closer" data-menu-close="true" role="button" tabindex="0">
#       </a>
#      </div>
#      <div class="p-offCanvasRegisterLink">
#       <div class="offCanvasMenu-linkHolder">
#        <a class="offCanvasMenu-link" data-menu-close="true" data-xf-click="overlay" href="https://www.smogon.com/forums/login/">
#         Log in
#        </a>
#       </div>
#       <hr class="offCanvasMenu-separator"/>
#       <div class="offCanvasMenu-linkHolder">
#        <a class="offCanvasMenu-link" data-menu-close="true" data-xf-click="overlay" href="https://www.smogon.com/forums/register/">
#         Register
#        </a>
#       </div>
#       <hr class="offCanvasMenu-separator"/>
#      </div>
#      <div class="js-offCanvasNavTarget">
#      </div>
#     </div>
#    </div>
#    <div class="p-body">
#     <div class="p-body-inner">
#      <!--XF:EXTRA_OUTPUT-->
#      <div class="lSSlideOuter noticeScrollContainer">
#       <div class="lSSlideWrapper usingCss" style="transition-duration: 400ms; transition-timing-function: ease;">
#        <ul class="notices notices--scrolling notices--isMulti js-notices lightSlider lSSlide" data-scroll-interval="6" data-type="scrolling" data-xf-init="notices" style="width: 5900px; transform: translate3d(-2360px, 0px, 0px); padding-bottom: 0%; height: 61.9792px;">
#         <li class="notice js-notice notice--primary clone left" data-auto-dismiss="" data-delay-duration="0" data-display-duration="0" data-notice-id="123" data-visibility="" style="width: 1180px; margin-right: 0px;">
#          <div class="notice-content">
#           <a class="notice-dismiss js-noticeDismiss" data-xf-init="tooltip" href="https://www.smogon.com/forums/account/dismiss-notice?notice_id=123" title="Dismiss notice">
#           </a>
#           Congrats to the winners of
#           <a href="https://www.smogon.com/forums/threads/3698704/">
#            the 2021 Smog Awards
#           </a>
#           !
#          </div>
#         </li>
#         <li class="notice js-notice notice--primary lslide" data-auto-dismiss="" data-delay-duration="0" data-display-duration="0" data-notice-id="88" data-visibility="" style="width: 1180px; margin-right: 0px;">
#          <div class="notice-content">
#           <a class="notice-dismiss js-noticeDismiss" data-original-title="Dismiss notice" data-xf-init="tooltip" href="https://www.smogon.com/forums/account/dismiss-notice?notice_id=88" id="js-XFUniqueId1">
#           </a>
#           The moderators of this forum are
#           <a href="https://www.smogon.com/forums/members/196780/">
#            Quite Quiet
#           </a>
#           ,
#           <a href="https://www.smogon.com/forums/members/265630/">
#            Amaranth
#           </a>
#           ,
#           <a href="https://www.smogon.com/forums/members/15630/">
#            august
#           </a>
#           ,
#           <a href="https://www.smogon.com/forums/members/114198/">
#            Finchinator
#           </a>
#           ,
#           <a href="https://www.smogon.com/forums/members/213064/">
#            Merritt
#           </a>
#           , and
#           <a href="https://www.smogon.com/forums/members/260369/">
#            TPP
#           </a>
#           .
#          </div>
#         </li>
#         <li class="notice js-notice notice--primary lslide active" data-auto-dismiss="" data-delay-duration="0" data-display-duration="0" data-notice-id="124" data-visibility="" style="width: 1180px; margin-right: 0px;">
#          <div class="notice-content">
#           <a class="notice-dismiss js-noticeDismiss" data-original-title="Dismiss notice" data-xf-init="tooltip" href="https://www.smogon.com/forums/account/dismiss-notice?notice_id=124" id="js-XFUniqueId2">
#           </a>
#           Welcome to Smogon! Take a moment to read the
#           <a href="https://www.smogon.com/forums/threads/3526346/">
#            <strong>
#             Introduction to Smogon
#            </strong>
#           </a>
#           for a run-down on everything Smogon, and make sure you take some time to read the
#           <a href="https://www.smogon.com/rules" target="_blank">
#            <strong>
#             global rules
#            </strong>
#           </a>
#           .
#          </div>
#         </li>
#         <li class="notice js-notice notice--primary lslide" data-auto-dismiss="" data-delay-duration="0" data-display-duration="0" data-notice-id="123" data-visibility="" style="width: 1180px; margin-right: 0px;">
#          <div class="notice-content">
#           <a class="notice-dismiss js-noticeDismiss" data-original-title="Dismiss notice" data-xf-init="tooltip" href="https://www.smogon.com/forums/account/dismiss-notice?notice_id=123" id="js-XFUniqueId3">
#           </a>
#           Congrats to the winners of
#           <a href="https://www.smogon.com/forums/threads/3698704/">
#            the 2021 Smog Awards
#           </a>
#           !
#          </div>
#         </li>
#         <li class="notice js-notice notice--primary clone right" data-auto-dismiss="" data-delay-duration="0" data-display-duration="0" data-notice-id="88" data-visibility="" style="width: 1180px; margin-right: 0px;">
#          <div class="notice-content">
#           <a class="notice-dismiss js-noticeDismiss" data-xf-init="tooltip" href="https://www.smogon.com/forums/account/dismiss-notice?notice_id=88" title="Dismiss notice">
#           </a>
#           The moderators of this forum are
#           <a href="https://www.smogon.com/forums/members/196780/">
#            Quite Quiet
#           </a>
#           ,
#           <a href="https://www.smogon.com/forums/members/265630/">
#            Amaranth
#           </a>
#           ,
#           <a href="https://www.smogon.com/forums/members/15630/">
#            august
#           </a>
#           ,
#           <a href="https://www.smogon.com/forums/members/114198/">
#            Finchinator
#           </a>
#           ,
#           <a href="https://www.smogon.com/forums/members/213064/">
#            Merritt
#           </a>
#           , and
#           <a href="https://www.smogon.com/forums/members/260369/">
#            TPP
#           </a>
#           .
#          </div>
#         </li>
#        </ul>
#       </div>
#       <ul class="lSPager lSpg" style="margin-top: 0px;">
#        <li class="">
#         <a href="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/#">
#          1
#         </a>
#        </li>
#        <li class="active">
#         <a href="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/#">
#          2
#         </a>
#        </li>
#        <li>
#         <a href="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/#">
#          3
#         </a>
#        </li>
#       </ul>
#      </div>
#      <ul class="p-breadcrumbs" itemscope="" itemtype="https://schema.org/BreadcrumbList">
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.smogon.com/" itemprop="item">
#         <span itemprop="name">
#          Home
#         </span>
#        </a>
#        <meta content="1" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.smogon.com/forums/" itemprop="item">
#         <span itemprop="name">
#          Forums
#         </span>
#        </a>
#        <meta content="2" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.smogon.com/forums/#competitive-play.213" itemprop="item">
#         <span itemprop="name">
#          Competitive Play
#         </span>
#        </a>
#        <meta content="3" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.smogon.com/forums/forums/tournaments.34/" itemprop="item">
#         <span itemprop="name">
#          Tournaments
#         </span>
#        </a>
#        <meta content="4" itemprop="position"/>
#       </li>
#       <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
#        <a href="https://www.smogon.com/forums/forums/official-ladder-tournament.465/" itemprop="item">
#         <span itemprop="name">
#          Official Ladder Tournament
#         </span>
#        </a>
#        <meta content="5" itemprop="position"/>
#       </li>
#      </ul>
#      <noscript>
#       <div class="blockMessage blockMessage--important blockMessage--iconic u-noJsOnly">
#        JavaScript is disabled. For a better experience, please enable JavaScript in your browser before proceeding.
#       </div>
#      </noscript>
#      <!--[if lt IE 9]><div class="blockMessage blockMessage&#45;&#45;important blockMessage&#45;&#45;iconic">You are using an out of date browser. It  may not display this or other websites correctly.<br />You should upgrade or use an <a href="https://www.google.com/chrome/browser/" target="_blank">alternative browser</a>.</div><![endif]-->
#      <div class="p-body-header">
#       <div class="p-title">
#        <h1 class="p-title-value">
#         Smogon's Official Ladder Tournament VIII - Replay Thread
#        </h1>
#       </div>
#       <div class="p-description">
#        <ul class="listInline listInline--bullet">
#         <li>
#          <i aria-hidden="true" class="fa--xf far fa-user" title="Thread starter">
#          </i>
#          <span class="u-srOnly">
#           Thread starter
#          </span>
#          <a class="username u-concealed" data-user-id="463545" data-xf-init="member-tooltip" dir="auto" href="https://www.smogon.com/forums/members/wigglytuff.463545/" id="js-XFUniqueId4">
#           Wigglytuff
#          </a>
#         </li>
#         <li>
#          <i aria-hidden="true" class="fa--xf far fa-clock" title="Start date">
#          </i>
#          <span class="u-srOnly">
#           Start date
#          </span>
#          <a class="u-concealed" href="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/">
#           <time class="u-dt" data-date-string="Aug 8, 2021" data-time="1628479456" data-time-string="11:24 PM" datetime="2021-08-08T23:24:16-0400" dir="auto" title="Aug 8, 2021 at 11:24 PM">
#            Aug 8, 2021
#           </time>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="p-body-main">
#       <div class="p-body-content">
#        <style>
#         #adholder {
# 	    height:100px;
# 	    display:flex;
# 	    align-items:center;
# 	}
#        </style>
#        <div id="adholder">
#         <div data-ref="vm-preloader" style="width: 728px; max-width: 728px; min-width: 728px; height: 90px; display: flex; flex-direction: column; justify-content: center; align-items: center; margin: 0px auto;">
#          <div class="vm-placement up-show" data-google-query-id="CK2o5YGkxvYCFYSZpwodPXUIHg" data-id="61c1e3b9058691726d94baec" data-pos="1001" data-reg="true" data-rejected="true" id="bt_1001-61c1e3b9058691726d94baec-1">
#           <div class="ahover" style="width: max-content !important; height: 90px; position: relative; z-index: 0; margin: 0px auto; display: block;">
#            <iframe marginheight="0" marginwidth="0" scrolling="no" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/safeFrame.html" style="width: 728px; height: 90px; border: 0px;">
#            </iframe>
#            <div class="upo-label" style="text-align: left; padding: 0px; margin: 0px; position: absolute; top: 0px; left: 0px; z-index: 10000; transition: opacity 1s ease-out 0s; opacity: 1;">
#             <span style="display:block;background:rgba(255, 255, 255, 0.7);height:fit-content;width:fit-content;top:0;left:0;color:#444;font-size:10px;font-weight:bold;font-family:sans-serif;line-height:normal;text-decoration:none;margin:0px;padding:6px;border-radius:0 0 5px 0;">
#              AD
#             </span>
#            </div>
#           </div>
#           <div id="google_ads_iframe_/21726375739,32698381/VM_613206cd1f2bbd4053f45a1d_AB_0__container__" style="border: 0pt none; display: inline-block; width: 1px; height: 1px;">
#            <iframe aria-label="Advertisement" data-google-container-id="1" data-is-safeframe="true" data-load-complete="true" frameborder="0" height="1" id="google_ads_iframe_/21726375739,32698381/VM_613206cd1f2bbd4053f45a1d_AB_0" marginheight="0" marginwidth="0" name="" role="region" sandbox="allow-forms allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" scrolling="no" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/container.html" style="border: 0px; vertical-align: bottom;" tabindex="0" title="3rd party ad content" width="1">
#            </iframe>
#           </div>
#          </div>
#         </div>
#         <div class="vm-placement" data-id="61c19cf10b7b5c349cf3c576" data-pos="1000" data-reg="true" id="61c19cf10b7b5c349cf3c576-1000">
#         </div>
#        </div>
#        <div class="p-body-pageContent">
#         <div class="block block--messages" data-href="/forums/inline-mod/" data-type="post" data-xf-init="">
#          <div class="block-outer">
#          </div>
#          <div class="block-outer js-threadStatusField">
#          </div>
#          <div class="block-container lbContainer" data-lb-id="thread-3689040" data-lb-universal="0" data-message-selector=".js-post" data-xf-init="lightbox select-to-quote">
#           <div class="block-body js-replyNewMessageContainer">
#            <article class="message message--post js-post js-inlineModContainer" data-author="Wigglytuff" data-content="post-8940860" id="js-post-8940860">
#             <span class="u-anchorTarget" id="post-8940860">
#             </span>
#             <div class="message-inner">
#              <div class="message-cell message-cell--user">
#               <section class="message-user" itemscope="" itemtype="https://schema.org/Person">
#                <div class="message-avatar">
#                 <div class="message-avatar-wrapper">
#                  <a class="avatar avatar--m" data-user-id="463545" data-xf-init="member-tooltip" href="https://www.smogon.com/forums/members/wigglytuff.463545/" id="js-XFUniqueId5">
#                   <img alt="Wigglytuff" class="avatar-u463545-m" itemprop="image" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/463545.jpg"/>
#                  </a>
#                 </div>
#                </div>
#                <div class="message-userDetails">
#                 <h4 class="message-name">
#                  <a class="username" data-user-id="463545" data-xf-init="member-tooltip" dir="auto" href="https://www.smogon.com/forums/members/wigglytuff.463545/" id="js-XFUniqueId6" itemprop="name">
#                   Wigglytuff
#                  </a>
#                 </h4>
#                 <div class="message-userBadges">
#                  <img alt="is a Community Contributor" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/cc.png.m.1" title="is a Community Contributor"/>
#                  <img alt="is a Tiering Contributor" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/tc.png.m.1" title="is a Tiering Contributor"/>
#                 </div>
#                </div>
#                <span class="message-userArrow">
#                </span>
#               </section>
#              </div>
#              <div class="message-cell message-cell--main">
#               <div class="message-main js-quickEditTarget">
#                <header class="message-attribution message-attribution--split">
#                 <div class="message-attribution-main">
#                  <a class="u-concealed" href="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/post-8940860" rel="nofollow">
#                   <time class="u-dt" data-date-string="Aug 8, 2021" data-time="1628479456" data-time-string="11:24 PM" datetime="2021-08-08T23:24:16-0400" dir="auto" title="Aug 8, 2021 at 11:24 PM">
#                    Aug 8, 2021
#                   </time>
#                  </a>
#                 </div>
#                 <ul class="message-attribution-opposite message-attribution-opposite--list">
#                  <li>
#                   <a data-href="/forums/posts/8940860/share" data-xf-init="share-tooltip" href="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/post-8940860" id="js-XFUniqueId7" rel="nofollow">
#                    <i aria-hidden="true" class="fa--xf far fa-share-alt">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a href="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-replay-thread.3689040/post-8940860" rel="nofollow">
#                    #1
#                   </a>
#                  </li>
#                 </ul>
#                </header>
#                <div class="message-content js-messageContent">
#                 <div class="message-userContent lbContainer js-lbContainer" data-lb-caption-desc="Wigglytuff · Aug 8, 2021 at 11:24 PM" data-lb-id="post-8940860">
#                  <article class="message-body js-selectToQuote">
#                   <div class="bbWrapper">
#                    <div style="text-align: center">
#                     <div class="lbContainer lbContainer--inline lbContainer--canZoom" data-lb-container-zoom="1" data-lb-id="_xfUid-1-1647284239" data-lb-single-image="1" data-lb-trigger=".js-lbImage-_xfUid-1-1647284239" data-xf-init="lightbox" title="">
#                      <div aria-label="Zoom" class="lbContainer-zoomer js-lbImage-_xfUid-1-1647284239" data-src="//i.imgur.com/NIOBj00.png">
#                      </div>
#                      <img class="bbImage" data-url="https://i.imgur.com/NIOBj00.png" data-zoom-target="1" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/NIOBj00.png" style=""/>
#                     </div>
#                     <br/>
#                     <i>
#                      <span style="font-size: 12px">
#                       (art by ium) (thread format stolen from
#                       <a class="username" data-user-id="62958" data-xf-init="member-tooltip" href="https://www.smogon.com/forums/members/62958/" id="js-XFUniqueId8">
#                        Vileman
#                       </a>
#                       )
#                      </span>
#                     </i>
#                     <br/>
#                     <br/>
#                     This thread is a collection of the replays in the playoffs stage of Official Ladder Tournament VIII. For information on the format of OLT, please read the
#                     <a class="link link--internal" href="https://www.smogon.com/forums/threads/smogons-official-ladder-tournament-viii-introduction.3686764/">
#                      introductory thread.
#                     </a>
#                     <br/>
#                     <br/>
#                     <img alt=":clefable:" class="smilie" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/clefable.png" style="vertical-align: middle"/>
#                     -
#                     <b>
#                      Round 1
#                     </b>
#                     -
#                     <img alt=":clefable:" class="smilie" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/clefable.png" style="vertical-align: middle"/>
#                     <br/>
#                     <a class="username" data-user-id="472348" data-xf-init="member-tooltip" href="https://www.smogon.com/forums/members/472348/" id="js-XFUniqueId9">
#                      Sagiri
#                     </a>
#                     vs
#                     <a class="username" data-user-id="472836" data-xf-init="member-tooltip" href="https://www.smogon.com/forums/members/472836/" id="js-XFUniqueId10">
#                      Ahsan-219
#                     </a>
#                     -
#                     <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572330" rel="nofollow noopener" target="_blank">
#                      1
#                     </a>
#                     |
#                     <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572331" rel="nofollow noopener" target="_blank">
#                      2
#                     </a>
#                     |
#                     <a class="link link--external" href="https://www.youtube.com/watch?v=cqNLvrfgw3c" rel="nofollow noopener" target="_blank">
#                      3
#                     </a>
#                     <br/>
#                     <a class="username" data-user-id="310107" data-xf-init="member-tooltip" href="https://www.smogon.com/forums/members/310107/" id="js-XFUniqueId11">
#                      Punny
#                     </a>
#                     vs
#                     <a class="username" data-user-id="306004" data-xf-init="member-tooltip" href="https://www.smogon.com/forums/members/306004/" id="js-XFUniqueId12">
#                      Lusa
#                     </a>
#                     -
#                     <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572833" rel="nofollow noopener" target="_blank">
#                      1
#                     </a>
#                     |
#                     <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572845" rel="nofollow noopener" target="_blank">
#                      2
#                     </a>
#                     |
#                     <a class="link link--external" href="https://www.youtube.com/watch?v=cqNLvrfgw3c" rel="nofollow noopener" target="_blank">
#                      3
#                     </a>
#                     <br/>
#                     <a class="username" data-user-id="405902" data-xf-init="member-tooltip" href="https://www.smogon.com/forums/members/405902/" id="js-XFUniqueId13">
#                      haxrme
#                     </a>
#                     vs
# ...
# 			day2: "Tuesday",
# 			day3: "Wednesday",
# 			day4: "Thursday",
# 			day5: "Friday",
# 			day6: "Saturday",
#
# 			dayShort0: "Sun",
# 			dayShort1: "Mon",
# 			dayShort2: "Tue",
# 			dayShort3: "Wed",
# 			dayShort4: "Thu",
# 			dayShort5: "Fri",
# 			dayShort6: "Sat",
#
# 			month0: "January",
# 			month1: "February",
# 			month2: "March",
# 			month3: "April",
# 			month4: "May",
# 			month5: "June",
# 			month6: "July",
# 			month7: "August",
# 			month8: "September",
# 			month9: "October",
# 			month10: "November",
# 			month11: "December",
#
# 			active_user_changed_reload_page: "The active user has changed. Reload the page for the latest version.",
# 			server_did_not_respond_in_time_try_again: "The server did not respond in time. Please try again.",
# 			oops_we_ran_into_some_problems: "Oops! We ran into some problems.",
# 			oops_we_ran_into_some_problems_more_details_console: "Oops! We ran into some problems. Please try again later. More error details may be in the browser console.",
# 			file_too_large_to_upload: "The file is too large to be uploaded.",
# 			uploaded_file_is_too_large_for_server_to_process: "The uploaded file is too large for the server to process.",
# 			files_being_uploaded_are_you_sure: "Files are still being uploaded. Are you sure you want to submit this form?",
# 			attach: "Attach files",
# 			rich_text_box: "Rich text box",
# 			close: "Close",
# 			link_copied_to_clipboard: "Link copied to clipboard.",
# 			text_copied_to_clipboard: "Text copied to clipboard.",
# 			loading: "Loading…",
#
# 			processing: "Processing",
# 			'processing...': "Processing…",
#
# 			showing_x_of_y_items: "Showing {count} of {total} items",
# 			showing_all_items: "Showing all items",
# 			no_items_to_display: "No items to display",
#
# 			push_enable_notification_title: "Push notifications enabled successfully at Smogon Forums",
# 			push_enable_notification_body: "Thank you for enabling push notifications!"
# 		});
#   </script>
#   <form hidden="hidden" style="display:none">
#    <input id="_xfClientLoadTime" name="_xfClientLoadTime" tabindex="-1" title="_xfClientLoadTime" type="text" value=""/>
#   </form>
#   <script id="xfReactTooltipTemplate" type="text/template">
#    <div class="tooltip-content-inner">
# 			<div class="reactTooltip">
#
# 					<a href="#" class="reaction reaction--1" data-reaction-id="1"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Like" title="Like" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 					<a href="#" class="reaction reaction--2" data-reaction-id="2"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Love" title="Love" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 					<a href="#" class="reaction reaction--3" data-reaction-id="3"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Haha" title="Haha" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 					<a href="#" class="reaction reaction--4" data-reaction-id="4"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Wow" title="Wow" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 					<a href="#" class="reaction reaction--5" data-reaction-id="5"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Sad" title="Sad" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 					<a href="#" class="reaction reaction--6" data-reaction-id="6"><i aria-hidden="true"></i><img src="..." class="reaction-sprite js-reaction" alt="Angry" title="Angry" data-xf-init="tooltip" data-extra-class="tooltip--basic tooltip--noninteractive" /></a>
#
# 			</div>
# 		</div>
#   </script>
#   <script type="application/ld+json">
#    {
# 			"@context": "https://schema.org",
# 			"@type": "DiscussionForumPosting",
# 			"@id": "https:\/\/www.smogon.com\/forums\/threads\/smogons-official-ladder-tournament-viii-replay-thread.3689040\/",
# 			"headline": "Smogon's Official Ladder Tournament VIII - Replay Thread",
# 			"articleBody": "(art by ium) (thread format stolen from Vileman)\n\nThis thread is a collection of the replays in the playoffs stage of Official Ladder Tournament VIII. For information on the format of OLT, please read the introductory thread.\n\n:clefable: - Round 1 - :clefable:\nSagiri vs Ahsan-219 - 1 | 2 | 3\nPunny vs Lusa - 1 | 2 | 3\nhaxrme vs devin - 1 | 2 | 3\nMichaelderBeste2 vs ABR - 1 | 2 | 3\nTace vs Tricking - 1 | 2 | 3\nInsult vs Chaitanya - 1 | 2 | 3\nTDNT vs Ayoukoo - 1 | 2 | 3\nEmpo vs BIHI - 1 | 2 | 3\nRubyblood vs Ox the Fox - 1 | 2 | 3\neclipseY vs Misterioussaint - 1 | 2 | 3\nHSA vs Eternal Spirit - 1 | 2 | 3\nGray vs Lord_Enz - 1 | 2 | 3\nbeatiful vs SoulWind - 1 | 2 | 3\nJohn W vs UnzipsCrogre - 1 | 2 | 3\nStorm Zone vs Flex OKLM - 1 | 2 | 3\nBushtush vs SpookyZ - 1 | 2 | 3\n\n:urshifu-rapid-strike: - Round 2 - :urshifu-rapid-strike:\n1-0\nMisterioussaint vs Ayoukoo - 1 | 2 | 3\nABR vs Insult - 1 | 2 | 3\nSagiri vs Storm Zone - 1 | 2 | 3\nTricking vs Ox the Fox - 1 | 2 | 3\nEternal Spirit vs Empo - 1 | 2 | 3\nLord_Enz vs SoulWind - 1 | 2 | 3\ndevin vs Lusa - 1 | 2 | 3\nJohn W vs SpookyZ - 1 | 2 | 3\n\n0-1\nPunny vs BIHI - 1 | 2 | 3\nTDNT vs Bushtush - 1 | 2 | 3\nbeatiful vs Rubyblood - 1 | 2 | 3\nMichaelderBeste2 vs Chaitanya - 1 | 2 | 3\neclipseY vs HSA - 1 | 2 | 3\nhaxrme vs Ahsan-219 - 1 | 2 | 3\nFlex OKLM vs UnzipsCrogre - 1 | 2 | 3\nGray vs Tace - 1 | 2 | 3\n\n\n:dragapult: - Round 3 - :dragapult:\n2-0\nMisterioussaint vs Insult - 1, 2, 3\nSoulWind vs Empo - 1, 2, 3\nTricking vs Lusa - 1, 2, 3\nJohn W vs Storm Zone - 1, 2, 3\n\n1-1\nMichaelderBeste2 vs Sagiri - 1, 2, 3\nOx the Fox vs SpookyZ - 1, 2, 3\nEternal Spirit vs Ayoukoo - 1, 2, 3\nBushtush vs Lord_Enz - 1, 2, 3\nbeatiful vs Flex OKLM - 1, 2, 3\nABR vs Gray - 1, 2, 3\ndevin vs BIHI - 1, 2, 3\nHSA vs Ahsan-219 - 1, 2, 3\n\n0-2\nRubyblood vs Tace - 1, 2, 3\nChaitanya vs eclipseY - 1, 2, 3\nhaxrme vs TDNT - 1, 2, 3\nUnzipsCrogre vs Punny - 1, 2, 3\n\n:weavile: - Round 4 - :weavile:\n2-1\nOx the Fox vs John W - 1, 2, 3\nMichaelderBeste2 vs Bushtush - 1, 2, 3\nbeatiful vs devin - 1, 2, 3\nABR vs Tricking - 1, 2, 3\nSoulWind vs Eternal Spirit - 1, 2, 3\nAhsan-219 vs Misterioussaint - 1, 2, 3\n\n1-2\nBIHI vs Ayoukoo - 1, 2, 3\nHSA vs Rubyblood - 1, 2, 3\nGray vs Sagiri - 1, 2, 3\nTDNT vs Chaitanya - 1, 2, 3\nPunny vs Flex OKLM - 1, 2, 3\nLord_Enz vs SpookyZ - 1, 2, 3\n\n:landorus-therian: - Round 5 - :landorus-therian:\n2-2\nSpookyZ vs beatiful - 1, 2, 3\nSagiri vs Eternal Spirit - 1, 2, 3\nAhsan-219 vs BIHI - 1, 2, 3\nJohn W vs Bushtush - 1, 2, 3\nTDNT vs Rubyblood - 1, 2, 3\nABR vs Punny - 1, 2, 3\n\n:corviknight: - Top 16 - :corviknight:\nMichaelderBeste2  vs  SoulWind - 1, 2, 3\nAhsan-219  vs  Rubyblood - 1, 2, 3\nEmpo  vs  Punny - 1, 2, 3\nSagiri  vs  Misterioussaint - 1, 2, 3\nBushtush  vs  Ox the Fox - 1, 2, 3\ndevin  vs  Insult - 1, 2, 3\nStorm Zone  vs  Tricking - 1, 2, 3\nLusa  vs  beatiful - 1, 2, 3\n\n:ferrothorn: - Quarterfinals - :ferrothorn:\nAhsan-219 vs SoulWind - 1, 2, 3\nOx the Fox vs beatiful - 1, 2, 3\nSagiri vs devin - 1, 2, 3\nPunny vs Storm Zone - 1, 2, 3\n\n:kartana: - Semifinals - :kartana:\nOx the Fox vs Punny - 1, 2, 3\ndevin vs SoulWind - 1, 2, 3\n\n:rillaboom: - Finals - :rillaboom:\nOx the Fox vs SoulWind - 1, 2, 3",
# 			"articleSection": "Official Ladder Tournament",
# 			"author": {
# 				"@type": "Person",
# 				"name": "Wigglytuff"
# 			},
# 			"datePublished": "2021-08-08",
# 			"dateModified": "2021-08-08",
# 			"image": "\/forums\/media\/data\/avatars\/l\/463\/463545.jpg?1607567998",
# 			"interactionStatistic": {
# 				"@type": "InteractionCounter",
# 				"interactionType": "https://schema.org/ReplyAction",
# 				"userInteractionCount": 0
# 			},
# 			"publisher": {
# 				"@type": "Organization",
# 				"name": "Smogon Forums",
# 				"logo": {
# 					"@type": "ImageObject",
# 					"url": "https:\/\/www.smogon.com\/forums\/media\/twitter.png"
# 				}
# 			},
# 			"mainEntityOfPage": {
# 				"@type": "WebPage",
# 				"@id": "https://www.smogon.com/forums"
# 			}
# 		}
#   </script>
#   <iframe src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/container(1).html" style="visibility: hidden; display: none;">
#   </iframe>
#   <iframe name="__tcfapiLocator" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/saved_resource(1).html" style="display: none;">
#   </iframe>
#   <img src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/favicon.ico" style="display: none !important; width: 1px !important; height: 1px !important;"/>
#   <img src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/px.gif" style="display: none !important; width: 1px !important; height: 1px !important;"/>
#   <div class="vm-skin vm-skin-right" style="width: 202px; margin-top: 10px; top: 45px; right: 0px; position: fixed; overflow: hidden; z-index: 997; visibility: visible;">
#    <div class="vm-skin-right-ads-container" style="top: 0px; position: relative; overflow: hidden;">
#    </div>
#   </div>
#   <iframe src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/safeFrame(1).html" style="width: 0px; height: 0px; display: none;">
#   </iframe>
#   <iframe frameborder="0" height="0" src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/syncframe.html" style="border-width: 0px; margin: 0px; display: none;" title="Criteo GUM iframe" width="0">
#   </iframe>
#   <script async="" type="text/javascript">
#    var xl8image = document.createElement("img"); xl8image.src = "https://load77.exelator.com/pixel.gif"; xl8image.width="0"; xl8image.height="0";xl8image.style="display: none;"; document.body.appendChild(xl8image);
#   </script>
#   <img height="0" style="display: none;" width="0"/>
#   <div class="tooltip tooltip--member tooltip--top" id="js-XFUniqueId178" role="tooltip" style="z-index: 306; display: none; bottom: -2119.27px; left: 565.292px;">
#    <div class="tooltip-arrow" style="left: 225px;">
#    </div>
#    <div class="tooltip-content">
#     <div class="tooltip-content-inner">
#      <div class="memberTooltip">
#       <div class="memberTooltip-header">
#        <span class="memberTooltip-avatar">
#         <a class="avatar avatar--m" data-user-id="440186" href="https://www.smogon.com/forums/members/john-w.440186/">
#          <img src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/ursaring.gif.m.1"/>
#         </a>
#        </span>
#        <div class="memberTooltip-headerInfo">
#         <h4 class="memberTooltip-name">
#          <a class="username" data-user-id="440186" dir="auto" href="https://www.smogon.com/forums/members/john-w.440186/">
#           <span class="username--style172">
#            John W
#           </span>
#          </a>
#         </h4>
#         <div class="memberTooltip-blurb">
#          <div class="" dir="auto">
#           <span class="userTitle" dir="auto">
#            Banned deucer.
#           </span>
#          </div>
#         </div>
#         <div class="memberTooltip-blurb">
#          <dl class="pairs pairs--inline">
#           <dt>
#            Joined
#           </dt>
#           <dd>
#            <time class="u-dt" data-date-string="Jan 8, 2018" data-time="1515447016" data-time-string="4:30 PM" datetime="2018-01-08T16:30:16-0500" dir="auto" title="Jan 8, 2018 at 4:30 PM">
#             Jan 8, 2018
#            </time>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </div>
#       <div class="memberTooltip-info">
#        <div class="memberTooltip-stats">
#         <div class="pairJustifier">
#          <dl class="pairs pairs--rows pairs--rows--centered fauxBlockLink">
#           <dt>
#            Messages
#           </dt>
#           <dd>
#            <a class="fauxBlockLink-linkRow u-concealed" href="https://www.smogon.com/forums/search/member?user_id=440186">
#             423
#            </a>
#           </dd>
#          </dl>
#          <dl class="pairs pairs--rows pairs--rows--centered">
#           <dt title="Reaction score">
#            Reaction score
#           </dt>
#           <dd>
#            4,267
#           </dd>
#          </dl>
#          <dl class="pairs pairs--rows pairs--rows--centered fauxBlockLink">
#           <dt title="Trophy points">
#            Points
#           </dt>
#           <dd>
#            <a class="fauxBlockLink-linkRow u-concealed" data-xf-click="overlay" href="https://www.smogon.com/forums/members/john-w.440186/trophies">
#             0
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="tooltip tooltip--member tooltip--top" id="js-XFUniqueId179" role="tooltip" style="z-index: 306; display: none; bottom: -2296.19px; left: 641.281px;">
#    <div class="tooltip-arrow" style="left: 225px;">
#    </div>
#    <div class="tooltip-content">
#     <div class="tooltip-content-inner">
#      <div class="memberTooltip">
#       <div class="memberTooltip-header">
#        <span class="memberTooltip-avatar">
#         <a class="avatar avatar--m" data-user-id="445163" href="https://www.smogon.com/forums/members/misterioussaint.445163/">
#          <img src="./Smogon's Official Ladder Tournament VIII - Replay Thread _ Smogon Forums_files/klang.gif.m.1"/>
#         </a>
#        </span>
#        <div class="memberTooltip-headerInfo">
#         <h4 class="memberTooltip-name">
#          <a class="username" data-user-id="445163" dir="auto" href="https://www.smogon.com/forums/members/misterioussaint.445163/">
#           <span class="username--style172">
#            Misterioussaint
#           </span>
#          </a>
#         </h4>
#         <div class="memberTooltip-blurb">
#          <div class="" dir="auto">
#           <span class="userTitle" dir="auto">
#            Banned deucer.
#           </span>
#          </div>
#         </div>
#         <div class="memberTooltip-blurb">
#          <dl class="pairs pairs--inline">
#           <dt>
#            Joined
#           </dt>
#           <dd>
#            <time class="u-dt" data-date-string="Feb 12, 2018" data-time="1518451839" data-time-string="11:10 AM" datetime="2018-02-12T11:10:39-0500" dir="auto" title="Feb 12, 2018 at 11:10 AM">
#             Feb 12, 2018
#            </time>
#           </dd>
#          </dl>
#         </div>
#         <div class="memberTooltip-blurb">
#          <dl class="pairs pairs--inline">
#           <dt>
#            Last seen
#           </dt>
#           <dd dir="auto">
#            <time class="u-dt" data-date-string="Feb 21, 2022" data-time="1645484987" data-time-string="6:09 PM" datetime="2022-02-21T18:09:47-0500" dir="auto" title="Feb 21, 2022 at 6:09 PM">
#             Feb 21, 2022
#            </time>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </div>
#       <div class="memberTooltip-info">
#        <div class="memberTooltip-stats">
#         <div class="pairJustifier">
#          <dl class="pairs pairs--rows pairs--rows--centered fauxBlockLink">
#           <dt>
#            Messages
#           </dt>
#           <dd>
#            <a class="fauxBlockLink-linkRow u-concealed" href="https://www.smogon.com/forums/search/member?user_id=445163">
#             255
#            </a>
#           </dd>
#          </dl>
#          <dl class="pairs pairs--rows pairs--rows--centered">
#           <dt title="Reaction score">
#            Reaction score
#           </dt>
#           <dd>
#            384
#           </dd>
#          </dl>
#          <dl class="pairs pairs--rows pairs--rows--centered fauxBlockLink">
#           <dt title="Trophy points">
#            Points
#           </dt>
#           <dd>
#            <a class="fauxBlockLink-linkRow u-concealed" data-xf-click="overlay" href="https://www.smogon.com/forums/members/misterioussaint.445163/trophies">
#             0
#            </a>
#           </dd>
#          </dl>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
#  <grammarly-desktop-integration data-grammarly-shadow-root="true">
#  </grammarly-desktop-integration>
# </html>

# %%
usernames = soup.find_all('a', class_="username")
unames = []
for names in usernames:
    names = names.text.replace('','')
    if names != 'Wigglytuff'and names != "Vileman":
        unames.append(names)

# %%
print(unames)
# Out:
# ['Sagiri', 'Ahsan-219', 'Punny', 'Lusa', 'haxrme', 'devin', 'MichaelderBeste2', 'ABR', 'Tace', 'Tricking', 'Insult', 'Chaitanya', 'TDNT', 'Ayoukoo', 'Empo', 'BIHI', 'Rubyblood', 'Ox the Fox', 'eclipseY', 'Misterioussaint', 'HSA', 'Eternal Spirit', 'Gray', 'Lord_Enz', 'beatiful', 'SoulWind', 'John W', 'UnzipsCrogre', 'Storm Zone', 'Flex OKLM', 'Bushtush', 'SpookyZ', 'Misterioussaint', 'Ayoukoo', 'ABR', 'Insult', 'Sagiri', 'Storm Zone', 'Tricking', 'Ox the Fox', 'Eternal Spirit', 'Empo', 'Lord_Enz', 'SoulWind', 'devin', 'Lusa', 'John W', 'SpookyZ', 'Punny', 'BIHI', 'TDNT', 'Bushtush', 'beatiful', 'Rubyblood', 'MichaelderBeste2', 'Chaitanya', 'eclipseY', 'HSA', 'haxrme', 'Ahsan-219', 'Flex OKLM', 'UnzipsCrogre', 'Gray', 'Tace', 'Misterioussaint', 'Insult', 'SoulWind', 'Empo', 'Tricking', 'Lusa', 'John W', 'Storm Zone', 'MichaelderBeste2', 'Sagiri', 'Ox the Fox', 'SpookyZ', 'Eternal Spirit', 'Ayoukoo', 'Bushtush', 'Lord_Enz', 'beatiful', 'Flex OKLM', 'ABR', 'Gray', 'devin', 'BIHI', 'HSA', 'Ahsan-219', 'Rubyblood', 'Tace', 'Chaitanya', 'eclipseY', 'haxrme', 'TDNT', 'UnzipsCrogre', 'Punny', 'Ox the Fox', 'John W', 'MichaelderBeste2', 'Bushtush', 'beatiful', 'devin', 'ABR', 'Tricking', 'SoulWind', 'Eternal Spirit', 'Ahsan-219', 'Misterioussaint', 'BIHI', 'Ayoukoo', 'HSA', 'Rubyblood', 'Gray', 'Sagiri', 'TDNT', 'Chaitanya', 'Punny', 'Flex OKLM', 'Lord_Enz', 'SpookyZ', 'SpookyZ', 'beatiful', 'Sagiri', 'Eternal Spirit', 'Ahsan-219', 'BIHI', 'John W', 'Bushtush', 'TDNT', 'Rubyblood', 'ABR', 'Punny', 'MichaelderBeste2', 'SoulWind', 'Ahsan-219', 'Rubyblood', 'Empo', 'Punny', 'Sagiri', 'Misterioussaint', 'Bushtush', 'Ox the Fox', 'devin', 'Insult', 'Storm Zone', 'Tricking', 'Lusa', 'beatiful', 'Ahsan-219', 'SoulWind', 'Ox the Fox', 'beatiful', 'Sagiri', 'devin', 'Punny', 'Storm Zone', 'Ox the Fox', 'Punny', 'devin', 'SoulWind', 'Ox the Fox', 'SoulWind', 'John W', 'Misterioussaint']

# %%
setnames = set(unames)
finalnames = list(setnames)
print(len(finalnames))
print(finalnames)
# Out:
# 32
# ['Misterioussaint', 'eclipseY', 'Ahsan-219', 'Lord_Enz', 'Eternal Spirit', 'TDNT', 'John W', 'Ox the Fox', 'Chaitanya', 'HSA', 'Tace', 'Lusa', 'Storm Zone', 'Insult', 'BIHI', 'SoulWind', 'SpookyZ', 'Sagiri', 'ABR', 'MichaelderBeste2', 'devin', 'Gray', 'beatiful', 'Punny', 'Tricking', 'Empo', 'Flex OKLM', 'Rubyblood', 'UnzipsCrogre', 'Bushtush', 'Ayoukoo', 'haxrme']

# %%
linksoup = soup.find_all('a', class_= 'link link--external')

# %%
print(linksoup)
# Out:
# [<a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572330" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572331" rel="nofollow noopener" target="_blank">2</a>, <a class="link link--external" href="https://www.youtube.com/watch?v=cqNLvrfgw3c" rel="nofollow noopener" target="_blank">3</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572833" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572845" rel="nofollow noopener" target="_blank">2</a>, <a class="link link--external" href="https://www.youtube.com/watch?v=cqNLvrfgw3c" rel="nofollow noopener" target="_blank">3</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572276" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572277" rel="nofollow noopener" target="_blank">2</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572278" rel="nofollow noopener" target="_blank">3</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572661" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572664" rel="nofollow noopener" target="_blank">2</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572670" rel="nofollow noopener" target="_blank">3</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572172" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572173" rel="nofollow noopener" target="_blank">2</a>, <a class="link link--external" href="https://www.youtube.com/watch?v=cqNLvrfgw3c" rel="nofollow noopener" target="_blank">3</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572313" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572316" rel="nofollow noopener" target="_blank">2</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572319" rel="nofollow noopener" target="_blank">3</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572575" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572584" rel="nofollow noopener" target="_blank">2</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572588" rel="nofollow noopener" target="_blank">3</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572702" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572706" rel="nofollow noopener" target="_blank">2</a>, <a class="link link--external" href="https://www.youtube.com/watch?v=cqNLvrfgw3c" rel="nofollow noopener" target="_blank">3</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572808" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572814" rel="nofollow noopener" target="_blank">2</a>, <a class="link link--external" href="https://www.youtube.com/watch?v=cqNLvrfgw3c" rel="nofollow noopener" target="_blank">3</a>, <a class="link link--external" href="https://replay.pokemonshowdown.com/smogtours-gen8ou-572118" rel="nofollow noopener" target="_blank">1</a>, <a class="link link--external" href="https ...

# %%
links_temp = []
for x in linksoup:
    links_temp.append(x['href'])

# %%
print(links_temp)
# Out:
# ['https://replay.pokemonshowdown.com/smogtours-gen8ou-572330', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572331', 'https://www.youtube.com/watch?v=cqNLvrfgw3c', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572833', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572845', 'https://www.youtube.com/watch?v=cqNLvrfgw3c', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572276', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572277', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572278', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572661', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572664', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572670', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572172', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572173', 'https://www.youtube.com/watch?v=cqNLvrfgw3c', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572313', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572316', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572319', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572575', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572584', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572588', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572702', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572706', 'https://www.youtube.com/watch?v=cqNLvrfgw3c', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572808', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572814', 'https://www.youtube.com/watch?v=cqNLvrfgw3c', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572118', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572119', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572120', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572472', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572490', 'https://www.youtube.com/watch?v=cqNLvrfgw3c', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572323', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572324', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572325', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572423', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572425', 'https://www.youtube.com/watch?v=cqNLvrfgw3c', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572422', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572426', 'https://www.youtube.com/watch?v=cqNLvrfgw3c', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572494', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572497', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572500', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572091', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572101', 'https://www.youtube.com/watch?v=cqNLvrfgw3c', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573823', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573829', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573833', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-574251', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-574257', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573414', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573415', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-574006', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-574015', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573609', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573612', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573617', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573756', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573763', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573764', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573949', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573957', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572932', 'https://replay.pokemonshowdown.com/smogto ...

# %%
finallinks = []
for x in links_temp:
    if 'replay' in x:
        finallinks.append(x)

print(finallinks)
# Out:
# ['https://replay.pokemonshowdown.com/smogtours-gen8ou-572330', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572331', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572833', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572845', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572276', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572277', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572278', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572661', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572664', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572670', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572172', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572173', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572313', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572316', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572319', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572575', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572584', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572588', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572702', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572706', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572808', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572814', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572118', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572119', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572120', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572472', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572490', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572323', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572324', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572325', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572423', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572425', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572422', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572426', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572494', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572497', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572500', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572091', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572101', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573823', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573829', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573833', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-574251', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-574257', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573414', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573415', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-574006', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-574015', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573609', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573612', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573617', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573756', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573763', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573764', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573949', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573957', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572932', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-572935', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573920', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573925', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573929', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573692', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573693', 'https://replay.pokemonshowdown.com/smogtours-gen8ou-573694', 'https://replay.pokemonshowdown ...

# %%
import requests
#t = "https://replay.pokemonshowdown.com/smogtours-gen8ou-572172"
#f = requests.get(t)
#print(f.text)

# %%
#soup2 = BeautifulSoup(f.text, 'lxml')
#print(soup2)

# %%
#print(soup2.find_all('a', class_ = 'subtle'))

# %%
#p = []
#for x in soup2.find_all('a', class_ = 'subtle'):
#   p.append(x.text.replace('',''))

#print(p)

# %%
#logs = f.text.splitlines()
#winline = ""
#for i in logs:
#    if "win" in i:
#        winline = i
        
#print(winline)

# %%
def matchPlayerID(name):
    if(name == 'Sagiri I.' or name == 'Sagiri I'):
        return 'Sagiri'
    elif(name == 'Lopunny kicks'):
        return "Punny"
    elif(name == 'devwin'):
        return 'devin'
    elif(name == 'Tace㋛'):
        return 'Tace'
    elif(name == 'SCILLATRON9000' or name == 'SCILLATRON 9000' or name == 'uhuhuhu2'):
        return 'Tricking'
    elif(name == 'INSULT'):
        return 'Insult'
    elif(name == 'Ayouko'):
        return 'Ayoukoo'
    elif(name == 'BIHI Gregson' or name == 'BIHI Asogi' or name == 'Cotisation URSSAF'):
        return 'BIHI'
    elif(name == 'EclipseY'):
        return 'eclipseY'
    elif(name == 'misterioussaint'):
        return 'Misterioussaint'
    elif(name == 'hsa'):
        return 'HSA'
    elif(name == 'imjustgray'):
        return 'Gray'
    elif(name == 'LordEnz'):
        return 'Lord_Enz'
    elif(name == 'Bbeeaa' or name == 'FREE XIMRAPTOR' or name == 'Freeximraptor'):
        return 'beatiful'
    elif(name == 'SOULWIND'):
        return 'SoulWind'
    elif(name == 'john w'):
        return 'John W'
    elif(name == 'storm zone'):
        return 'Storm Zone'
    else:
        return name

# %%
import requests
edges = []
for x in finallinks:
    battlefile = requests.get(x)
    temp_soup = BeautifulSoup(battlefile.text, 'lxml')
    players = []
    for y in temp_soup.find_all('a', class_ = 'subtle'):
        players.append(y.text.replace('',''))
    logs = battlefile.text.splitlines()
    winline = ""
    for i in logs:
        if "win" in i:
            winline = i
    if players[0] in winline:
        edges.append([matchPlayerID(players[1]) , matchPlayerID(players[0])]) 
    elif players[1] in winline:
        edges.append([matchPlayerID(players[0]) , matchPlayerID(players[1])])

# %%
print(edges)
# Out:
# [['Ahsan-219', 'Sagiri'], ['Ahsan-219', 'Sagiri'], ['Punny', 'Lusa'], ['Punny', 'Lusa'], ['haxrme', 'devin'], ['devin', 'haxrme'], ['haxrme', 'devin'], ['MichaelderBeste2', 'ABR'], ['ABR', 'MichaelderBeste2'], ['MichaelderBeste2', 'ABR'], ['Tace', 'Tricking'], ['Tace', 'Tricking'], ['Chaitanya', 'Insult'], ['Insult', 'Chaitanya'], ['Chaitanya', 'Insult'], ['TDNT', 'Ayoukoo'], ['Ayoukoo', 'TDNT'], ['TDNT', 'Ayoukoo'], ['BIHI', 'Empo'], ['BIHI', 'Empo'], ['Rubyblood', 'Ox the Fox'], ['Rubyblood', 'Ox the Fox'], ['Misterioussaint', 'eclipseY'], ['eclipseY', 'Misterioussaint'], ['eclipseY', 'Misterioussaint'], ['HSA', 'Eternal Spirit'], ['HSA', 'Eternal Spirit'], ['Gray', 'Lord_Enz'], ['Lord_Enz', 'Gray'], ['Gray', 'Lord_Enz'], ['beatiful', 'SoulWind'], ['beatiful', 'SoulWind'], ['UnzipsCrogre', 'John W'], ['UnzipsCrogre', 'John W'], ['Flex OKLM', 'Storm Zone'], ['Storm Zone', 'Flex OKLM'], ['Flex OKLM', 'Storm Zone'], ['Bushtush', 'SpookyZ'], ['Bushtush', 'SpookyZ'], ['Misterioussaint', 'Ayoukoo'], ['Ayoukoo', 'Misterioussaint'], ['Ayoukoo', 'Misterioussaint'], ['ABR', 'Insult'], ['ABR', 'Insult'], ['Sagiri', 'Storm Zone'], ['Sagiri', 'Storm Zone'], ['Ox the Fox', 'Tricking'], ['Ox the Fox', 'Tricking'], ['Eternal Spirit', 'Empo'], ['Empo', 'Eternal Spirit'], ['Eternal Spirit', 'Empo'], ['SoulWind', 'Lord_Enz'], ['Lord_Enz', 'SoulWind'], ['Lord_Enz', 'SoulWind'], ['devin', 'Lusa'], ['devin', 'Lusa'], ['SpookyZ', 'John W'], ['SpookyZ', 'John W'], ['BIHI', 'Punny'], ['Punny', 'BIHI'], ['Punny', 'BIHI'], ['TDNT', 'Bushtush'], ['Bushtush', 'TDNT'], ['TDNT', 'Bushtush'], ['beatiful', 'Rubyblood'], ['Rubyblood', 'beatiful'], ['Rubyblood', 'beatiful'], ['Chaitanya', 'MichaelderBeste2'], ['Chaitanya', 'MichaelderBeste2'], ['eclipseY', 'HSA'], ['eclipseY', 'HSA'], ['haxrme', 'Ahsan-219'], ['haxrme', 'Ahsan-219'], ['UnzipsCrogre', 'Flex OKLM'], ['UnzipsCrogre', 'Flex OKLM'], ['Tace', 'Gray'], ['Tace', 'Gray'], ['Misterioussaint', 'Insult'], ['Insult', 'Misterioussaint'], ['Misterioussaint', 'Insult'], ['Empo', 'SoulWind'], ['SoulWind', 'Empo'], ['SoulWind', 'Empo'], ['Lusa', 'Tricking'], ['Tricking', 'Lusa'], ['Tricking', 'Lusa'], ['John W', 'Storm Zone'], ['Storm Zone', 'John W'], ['John W', 'Storm Zone'], ['MichaelderBeste2', 'Sagiri'], ['Sagiri', 'MichaelderBeste2'], ['Sagiri', 'MichaelderBeste2'], ['SpookyZ', 'Ox the Fox'], ['SpookyZ', 'Ox the Fox'], ['Ayoukoo', 'Eternal Spirit'], ['Ayoukoo', 'Eternal Spirit'], ['Lord_Enz', 'Bushtush'], ['Lord_Enz', 'Bushtush'], ['Flex OKLM', 'beatiful'], ['Flex OKLM', 'beatiful'], ['Gray', 'ABR'], ['Gray', 'ABR'], ['devin', 'BIHI'], ['BIHI', 'devin'], ['BIHI', 'devin'], ['Ahsan-219', 'HSA'], ['Ahsan-219', 'HSA'], ['Ahsan-219', 'HSA'], ['Tace', 'Rubyblood'], ['Rubyblood', 'Tace'], ['Tace', 'Rubyblood'], ['haxrme', 'TDNT'], ['haxrme', 'TDNT'], ['UnzipsCrogre', 'Punny'], ['UnzipsCrogre', 'Punny'], ['Bushtush', 'MichaelderBeste2'], ['MichaelderBeste2', 'Bushtush'], ['Bushtush', 'MichaelderBeste2'], ['beatiful', 'devin'], ['beatiful', 'devin'], ['Tricking', 'ABR'], ['ABR', 'Tricking'], ['ABR', 'Tricking'], ['SoulWind', 'Eternal Spirit'], ['Eternal Spirit', 'SoulWind'], ['Eternal Spirit', 'SoulWind'], ['Misterioussaint', 'Ahsan-219'], ['Ahsan-219', 'Misterioussaint'], ['Ahsan-219', 'Misterioussaint'], ['Ayoukoo', 'BIHI'], ['Ayoukoo', 'BIHI'], ['HSA', 'Rubyblood'], ['HSA', 'Rubyblood'], ['Gray', 'Sagiri'], ['Sagiri', 'Gray'], ['Gray', 'Sagiri'], ['Chaitanya', 'TDNT'], ['TDNT', 'Chaitanya'], ['Chaitanya', 'TDNT'], ['Flex OKLM', 'Punny'], ['Flex OKLM', 'Punny'], ['Lord_Enz', 'SpookyZ'], ['SpookyZ', 'Lord_Enz'], ['Lord_Enz', 'SpookyZ'], ['SpookyZ', 'beatiful'], ['SpookyZ', 'beatiful'], ['Eternal Spirit', 'Sagiri'], ['Eternal Spirit', 'Sagiri'], ['Ahsan-219', 'BIHI'], ['BIHI', 'Ahsan-219'], ['BIHI', 'Ahsan-219'], ['TDNT', 'Rubyblood'], ['Rubyblood', 'TDNT'], ['TDNT', 'Rubyblood'], ['ABR', 'Punny'], ['Punny', 'ABR'], ['ABR', 'Punny'], ['MichaelderBeste2', 'SoulWind'], ['SoulWind', 'MichaelderBeste2'], ['Michaelde ...

# %%
import networkx as nx

G = nx.DiGraph()
G.add_nodes_from(finalnames)
G.add_edges_from(edges)

# %%
PRank = nx.pagerank(G, alpha=0.85, personalization=None, weight='weight', dangling=None)

# %%
print(PRank)
# Out:
# {'Misterioussaint': 0.02549965177329615, 'eclipseY': 0.009022649901286463, 'Ahsan-219': 0.03160954918986624, 'Lord_Enz': 0.021747604852309147, 'Eternal Spirit': 0.03303380571697398, 'TDNT': 0.025928670934111803, 'John W': 0.028113365363534037, 'Ox the Fox': 0.04436152039609455, 'Chaitanya': 0.018713187791268952, 'HSA': 0.013895543857272609, 'Tace': 0.00933498250829307, 'Lusa': 0.04349759555810308, 'Storm Zone': 0.0672786447495486, 'Insult': 0.03005751430513458, 'BIHI': 0.029936072361592465, 'SoulWind': 0.058932448928755335, 'SpookyZ': 0.014283127653085655, 'Sagiri': 0.03801973780668112, 'ABR': 0.042462647915019705, 'MichaelderBeste2': 0.040416163769665, 'devin': 0.039463677709693015, 'Gray': 0.020033363261949478, 'beatiful': 0.05053089513200319, 'Punny': 0.07114100345622383, 'Tricking': 0.0474117254184601, 'Empo': 0.03883544300020633, 'Flex OKLM': 0.02507824545987253, 'Rubyblood': 0.027338199181903146, 'UnzipsCrogre': 0.004687500000000001, 'Bushtush': 0.023406739632385303, 'Ayoukoo': 0.014532384520241727, 'haxrme': 0.011396337895168654}

# %%
print(type(PRank))
# Out:
# <class 'dict'>

# %%
sorted(PRank.items(), key=lambda x: x[1])
# Out:
# [('UnzipsCrogre', 0.004687500000000001),
#  ('eclipseY', 0.009022649901286463),
#  ('Tace', 0.00933498250829307),
#  ('haxrme', 0.011396337895168654),
#  ('HSA', 0.013895543857272609),
#  ('SpookyZ', 0.014283127653085655),
#  ('Ayoukoo', 0.014532384520241727),
#  ('Chaitanya', 0.018713187791268952),
#  ('Gray', 0.020033363261949478),
#  ('Lord_Enz', 0.021747604852309147),
#  ('Bushtush', 0.023406739632385303),
#  ('Flex OKLM', 0.02507824545987253),
#  ('Misterioussaint', 0.02549965177329615),
#  ('TDNT', 0.025928670934111803),
#  ('Rubyblood', 0.027338199181903146),
#  ('John W', 0.028113365363534037),
#  ('BIHI', 0.029936072361592465),
#  ('Insult', 0.03005751430513458),
#  ('Ahsan-219', 0.03160954918986624),
#  ('Eternal Spirit', 0.03303380571697398),
#  ('Sagiri', 0.03801973780668112),
#  ('Empo', 0.03883544300020633),
#  ('devin', 0.039463677709693015),
#  ('MichaelderBeste2', 0.040416163769665),
#  ('ABR', 0.042462647915019705),
#  ('Lusa', 0.04349759555810308),
#  ('Ox the Fox', 0.04436152039609455),
#  ('Tricking', 0.0474117254184601),
#  ('beatiful', 0.05053089513200319),
#  ('SoulWind', 0.058932448928755335),
#  ('Storm Zone', 0.0672786447495486),
#  ('Punny', 0.07114100345622383)]

# %%
dictWin = {i : 0 for i in finalnames}
dictLoss = {i : 0 for i in finalnames}
for x in edges:
    dictLoss[x[0]] = dictLoss[x[0]] + 1
    dictWin[x[1]] = dictWin[x[0]] + 1

# %%
print(dictWin)
# Out:
# {'Misterioussaint': 8, 'eclipseY': 1, 'Ahsan-219': 11, 'Lord_Enz': 4, 'Eternal Spirit': 6, 'TDNT': 7, 'John W': 4, 'Ox the Fox': 12, 'Chaitanya': 4, 'HSA': 4, 'Tace': 2, 'Lusa': 7, 'Storm Zone': 10, 'Insult': 4, 'BIHI': 8, 'SoulWind': 11, 'SpookyZ': 5, 'Sagiri': 9, 'ABR': 8, 'MichaelderBeste2': 8, 'devin': 10, 'Gray': 3, 'beatiful': 10, 'Punny': 13, 'Tricking': 7, 'Empo': 8, 'Flex OKLM': 1, 'Rubyblood': 8, 'UnzipsCrogre': 0, 'Bushtush': 5, 'Ayoukoo': 3, 'haxrme': 2}

# %%
print(dictLoss)
# Out:
# {'Misterioussaint': 7, 'eclipseY': 4, 'Ahsan-219': 10, 'Lord_Enz': 7, 'Eternal Spirit': 6, 'TDNT': 7, 'John W': 2, 'Ox the Fox': 4, 'Chaitanya': 6, 'HSA': 4, 'Tace': 6, 'Lusa': 3, 'Storm Zone': 4, 'Insult': 4, 'BIHI': 7, 'SoulWind': 8, 'SpookyZ': 7, 'Sagiri': 7, 'ABR': 7, 'MichaelderBeste2': 6, 'devin': 7, 'Gray': 6, 'beatiful': 8, 'Punny': 9, 'Tricking': 5, 'Empo': 4, 'Flex OKLM': 6, 'Rubyblood': 8, 'UnzipsCrogre': 6, 'Bushtush': 7, 'Ayoukoo': 7, 'haxrme': 6}

# %%
dictWinLoss = {i : 0 for i in finalnames}
for key in dictWinLoss:
    dictWinLoss[key] = dictWin[key]/dictLoss[key]

# %%
print(dictWinLoss)
# Out:
# {'Misterioussaint': 1.1428571428571428, 'eclipseY': 0.25, 'Ahsan-219': 1.1, 'Lord_Enz': 0.5714285714285714, 'Eternal Spirit': 1.0, 'TDNT': 1.0, 'John W': 2.0, 'Ox the Fox': 3.0, 'Chaitanya': 0.6666666666666666, 'HSA': 1.0, 'Tace': 0.3333333333333333, 'Lusa': 2.3333333333333335, 'Storm Zone': 2.5, 'Insult': 1.0, 'BIHI': 1.1428571428571428, 'SoulWind': 1.375, 'SpookyZ': 0.7142857142857143, 'Sagiri': 1.2857142857142858, 'ABR': 1.1428571428571428, 'MichaelderBeste2': 1.3333333333333333, 'devin': 1.4285714285714286, 'Gray': 0.5, 'beatiful': 1.25, 'Punny': 1.4444444444444444, 'Tricking': 1.4, 'Empo': 2.0, 'Flex OKLM': 0.16666666666666666, 'Rubyblood': 1.0, 'UnzipsCrogre': 0.0, 'Bushtush': 0.7142857142857143, 'Ayoukoo': 0.42857142857142855, 'haxrme': 0.3333333333333333}

# %%
sorted(dictWinLoss.items(), key=lambda x: x[1])
# Out:
# [('UnzipsCrogre', 0.0),
#  ('Flex OKLM', 0.16666666666666666),
#  ('eclipseY', 0.25),
#  ('Tace', 0.3333333333333333),
#  ('haxrme', 0.3333333333333333),
#  ('Ayoukoo', 0.42857142857142855),
#  ('Gray', 0.5),
#  ('Lord_Enz', 0.5714285714285714),
#  ('Chaitanya', 0.6666666666666666),
#  ('SpookyZ', 0.7142857142857143),
#  ('Bushtush', 0.7142857142857143),
#  ('Eternal Spirit', 1.0),
#  ('TDNT', 1.0),
#  ('HSA', 1.0),
#  ('Insult', 1.0),
#  ('Rubyblood', 1.0),
#  ('Ahsan-219', 1.1),
#  ('Misterioussaint', 1.1428571428571428),
#  ('BIHI', 1.1428571428571428),
#  ('ABR', 1.1428571428571428),
#  ('beatiful', 1.25),
#  ('Sagiri', 1.2857142857142858),
#  ('MichaelderBeste2', 1.3333333333333333),
#  ('SoulWind', 1.375),
#  ('Tricking', 1.4),
#  ('devin', 1.4285714285714286),
#  ('Punny', 1.4444444444444444),
#  ('John W', 2.0),
#  ('Empo', 2.0),
#  ('Lusa', 2.3333333333333335),
#  ('Storm Zone', 2.5),
#  ('Ox the Fox', 3.0)]
